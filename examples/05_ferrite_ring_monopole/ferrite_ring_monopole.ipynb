# %% [markdown]
# ## Docker specific configurations
#
# Prepare python path

# %%
from sys import path
from pathlib import Path
path.append(str(Path("../../").resolve()))

# %% [markdown]
# ## Prepare mesh
#
# Generate mesh outside of the docker using the following commans:
# ```bash
# gmsh mesh.geo -2
# ../../tools/convert_msh.py mesh.msh mesh.xdmf
# ```

# %% [markdown]
# ## Solution preparation
#
# Import BeamImpedance2D module

# %%
import logging
import bi2d
from bi2d.esum import Esum
from bi2d.materials import vacuum, beam, mischung43
import numpy as np

# %% [markdown]
# Assign material indices

# %%
beam.index = 1
vacuum.index = 2
mischung43.index = 3

# %% [markdown]
# Setup mesh and materials

# %%
m = bi2d.Mesh("mesh.xdmf")
mc = bi2d.MaterialMap(m, [beam, vacuum, mischung43])

# %% [markdown]
# Configure solution

# %%
solution = bi2d.Solution(mc, Hcurl_order=2, H1_order=2)

# %% [markdown]
# Enable info level logging

# %%
solution.logger.setLevel(logging.INFO)

# %% [markdown]
# ## Solve and visualize fields
#
# Solve and visualize the fields for one frequency point

# %%
solution.get_z([1e8], beta=0.9, source_function=bi2d.SourceFunction.MONOPOLE)
# Out:
# INFO:bi2d.solution:Solving for f=1.00e+08, β=0.90
# array([[1.00e+08, 4.13e+03, 9.00e+02]])

# %% [markdown]
# `Esum` object allows us to summate rotational and irrotational fields for visualization

# %%
esum = Esum(solution)
esum.solve()
solution.save("solution.xdmf")

# %% [markdown]
# Use `paraview solution.xdmf` command to visualize solution from desktop. Note, that `paraview` needs both `solution.xdmf` and `solution.h5` files.

# %% [markdown]
# ## Calculate impedance
#
# Calculate impedance in frequency range and save the results

# %%
# %%time

data = []
betas = [0.01, 0.05, 0.1, 0.5, 1.0]
for beta in betas:
    data.append(solution.get_z(np.logspace(5, 9, num=30), beta=beta, source_function=bi2d.SourceFunction.MONOPOLE))
# Out:
# INFO:bi2d.solution:Solving for f=1.00e+05, β=0.01
# INFO:bi2d.solution:Solving for f=1.37e+05, β=0.01
# INFO:bi2d.solution:Solving for f=1.89e+05, β=0.01
# INFO:bi2d.solution:Solving for f=2.59e+05, β=0.01
# INFO:bi2d.solution:Solving for f=3.56e+05, β=0.01
# INFO:bi2d.solution:Solving for f=4.89e+05, β=0.01
# INFO:bi2d.solution:Solving for f=6.72e+05, β=0.01
# INFO:bi2d.solution:Solving for f=9.24e+05, β=0.01
# INFO:bi2d.solution:Solving for f=1.27e+06, β=0.01
# INFO:bi2d.solution:Solving for f=1.74e+06, β=0.01
# INFO:bi2d.solution:Solving for f=2.40e+06, β=0.01
# INFO:bi2d.solution:Solving for f=3.29e+06, β=0.01
# INFO:bi2d.solution:Solving for f=4.52e+06, β=0.01
# INFO:bi2d.solution:Solving for f=6.21e+06, β=0.01
# INFO:bi2d.solution:Solving for f=8.53e+06, β=0.01
# INFO:bi2d.solution:Solving for f=1.17e+07, β=0.01
# INFO:bi2d.solution:Solving for f=1.61e+07, β=0.01
# INFO:bi2d.solution:Solving for f=2.21e+07, β=0.01
# INFO:bi2d.solution:Solving for f=3.04e+07, β=0.01
# INFO:bi2d.solution:Solving for f=4.18e+07, β=0.01
# INFO:bi2d.solution:Solving for f=5.74e+07, β=0.01
# INFO:bi2d.solution:Solving for f=7.88e+07, β=0.01
# INFO:bi2d.solution:Solving for f=1.08e+08, β=0.01
# INFO:bi2d.solution:Solving for f=1.49e+08, β=0.01
# INFO:bi2d.solution:Solving for f=2.04e+08, β=0.01
# INFO:bi2d.solution:Solving for f=2.81e+08, β=0.01
# INFO:bi2d.solution:Solving for f=3.86e+08, β=0.01
# INFO:bi2d.solution:Solving for f=5.30e+08, β=0.01
# INFO:bi2d.solution:Solving for f=7.28e+08, β=0.01
# INFO:bi2d.solution:Solving for f=1.00e+09, β=0.01
# INFO:bi2d.solution:Solving for f=1.00e+05, β=0.05
# INFO:bi2d.solution:Solving for f=1.37e+05, β=0.05
# INFO:bi2d.solution:Solving for f=1.89e+05, β=0.05
# INFO:bi2d.solution:Solving for f=2.59e+05, β=0.05
# INFO:bi2d.solution:Solving for f=3.56e+05, β=0.05
# INFO:bi2d.solution:Solving for f=4.89e+05, β=0.05
# INFO:bi2d.solution:Solving for f=6.72e+05, β=0.05
# INFO:bi2d.solution:Solving for f=9.24e+05, β=0.05
# INFO:bi2d.solution:Solving for f=1.27e+06, β=0.05
# INFO:bi2d.solution:Solving for f=1.74e+06, β=0.05
# INFO:bi2d.solution:Solving for f=2.40e+06, β=0.05
# INFO:bi2d.solution:Solving for f=3.29e+06, β=0.05
# INFO:bi2d.solution:Solving for f=4.52e+06, β=0.05
# INFO:bi2d.solution:Solving for f=6.21e+06, β=0.05
# INFO:bi2d.solution:Solving for f=8.53e+06, β=0.05
# INFO:bi2d.solution:Solving for f=1.17e+07, β=0.05
# INFO:bi2d.solution:Solving for f=1.61e+07, β=0.05
# INFO:bi2d.solution:Solving for f=2.21e+07, β=0.05
# INFO:bi2d.solution:Solving for f=3.04e+07, β=0.05
# INFO:bi2d.solution:Solving for f=4.18e+07, β=0.05
# INFO:bi2d.solution:Solving for f=5.74e+07, β=0.05
# INFO:bi2d.solution:Solving for f=7.88e+07, β=0.05
# INFO:bi2d.solution:Solving for f=1.08e+08, β=0.05
# INFO:bi2d.solution:Solving for f=1.49e+08, β=0.05
# INFO:bi2d.solution:Solving for f=2.04e+08, β=0.05
# INFO:bi2d.solution:Solving for f=2.81e+08, β=0.05
# INFO:bi2d.solution:Solving for f=3.86e+08, β=0.05
# INFO:bi2d.solution:Solving for f=5.30e+08, β=0.05
# INFO:bi2d.solution:Solving for f=7.28e+08, β=0.05
# INFO:bi2d.solution:Solving for f=1.00e+09, β=0.05
# INFO:bi2d.solution:Solving for f=1.00e+05, β=0.10
# INFO:bi2d.solution:Solving for f=1.37e+05, β=0.10
# INFO:bi2d.solution:Solving for f=1.89e+05, β=0.10
# INFO:bi2d.solution:Solving for f=2.59e+05, β=0.10
# INFO:bi2d.solution:Solving for f=3.56e+05, β=0.10
# INFO:bi2d.solution:Solving for f=4.89e+05, β=0.10
# INFO:bi2d.solution:Solving for f=6.72e+05, β=0.10
# INFO:bi2d.solution:Solving for f=9.24e+05, β=0.10
# INFO:bi2d.solution:Solving for f=1.27e+06, β=0.10
# INFO:bi2d.solution:Solving for f=1.74e+06, β=0.10
# INFO:bi2d.solution:Solving for f=2.40e+06, β=0.10
# INFO:bi2d.solution:Solving for f=3.29e+06, β=0.10
# INFO:bi2d.solution:Solving for f=4.52e+06, β=0.10
# INFO:bi2d.solution:Solving for f=6.21e+06, β=0.10
# INFO:bi2d.solution:Solving for f=8.53e+06, β=0.10
# INFO:bi2d.solution:Solving for f=1.17e+07, β=0.10
# INFO:bi2d.solution:Solving for f=1.61e+07, β=0.10
# INFO:bi2d.solution:Solving for f=2.21e+07, β=0.10
# INFO:bi2d.solution:Solving for f=3.04e+07, β=0.10
# INFO:bi2d.solution:Solving for f=4.18e+07, β=0.10
# INFO:bi2d.solution:Solving for f=5.74e+07, β=0.10
# INFO:bi2d.solution:Solving for f=7.88e+07, β=0.10
# INFO:bi2d.solution:Solving for f=1.08e+08, β=0.10
# INFO:bi2d.solution:Solving for f=1.49e+08, β=0.10
# INFO:bi2d.solution:Solving for f=2.04e+08, β=0.10
# INFO:bi2d.solution:Solving for f=2.81e+08, β=0.10
# INFO:bi2d.solution:Solving for f=3.86e+08, β=0.10
# INFO:bi2d.solution:Solving for f=5.30e+08, β=0.10
# INFO:bi2d.solution:Solving for f=7.28e+08, β=0.10
# INFO:bi2d.solution:Solving for f=1.00e+09, β=0.10
# INFO:bi2d.solution:Solving for f=1.00e+05, β=0.50
# INFO:bi2d.solution:Solving for f=1.37e+05, β=0.50
# INFO:bi2d.solution:Solving for f=1.89e+05, β=0.50
# INFO:bi2d.solution:Solving for f=2.59e+05, β=0.50
# INFO:bi2d.solution:Solving for f=3.56e+05, β=0.50
# INFO:bi2d.solution:Solving for f=4.89e+05, β=0.50
# INFO:bi2d.solution:Solving for f=6.72e+05, β=0.50
# INFO:bi2d.solution:Solving for f=9.24e+05, β=0.50
# INFO:bi2d.solution:Solving for f=1.27e+06, β=0.50
# INFO:bi2d.solution:Solving for f=1.74e+06, β=0.50
# INFO:bi2d.solution:Solving for f=2.40e+06, β=0.50
# INFO:bi2d.solution:Solving for f=3.29e+06, β=0.50
# INFO:bi2d.solution:Solving for f=4.52e+06, β=0.50
# INFO:bi2d.solution:Solving for f=6.21e+06, β=0.50
# INFO:bi2d.solution:Solving for f=8.53e+06, β=0.50
# INFO:bi2d.solution:Solving for f=1.17e+07, β=0.50
# INFO:bi2d.solution:Solving for f=1.61e+07, β=0.50
# INFO:bi2d.solution:Solving for f=2.21e+07, β=0.50
# INFO:bi2d.solution:Solving for f=3.04e+07, β=0.50
# INFO:bi2d.solution:Solving for f=4.18e+07, β=0.50
# INFO:bi2d.solution:Solving for f=5.74e+07, β=0.50
# INFO:bi2d.solution:Solving for f=7.88e+07, β=0.50
# INFO:bi2d.solution:Solving for f=1.08e+08, β=0.50
# INFO:bi2d.solution:Solving for f=1.49e+08, β=0.50
# INFO:bi2d.solution:Solving for f=2.04e+08, β=0.50
# INFO:bi2d.solution:Solving for f=2.81e+08, β=0.50
# INFO:bi2d.solution:Solving for f=3.86e+08, β=0.50
# INFO:bi2d.solution:Solving for f=5.30e+08, β=0.50
# INFO:bi2d.solution:Solving for f=7.28e+08, β=0.50
# INFO:bi2d.solution:Solving for f=1.00e+09, β=0.50
# INFO:bi2d.solution:Solving for f=1.00e+05, β=1.00
# INFO:bi2d.solution:Solving for f=1.37e+05, β=1.00
# INFO:bi2d.solution:Solving for f=1.89e+05, β=1.00
# INFO:bi2d.solution:Solving for f=2.59e+05, β=1.00
# INFO:bi2d.solution:Solving for f=3.56e+05, β=1.00
# INFO:bi2d.solution:Solving for f=4.89e+05, β=1.00
# INFO:bi2d.solution:Solving for f=6.72e+05, β=1.00
# INFO:bi2d.solution:Solving for f=9.24e+05, β=1.00
# INFO:bi2d.solution:Solving for f=1.27e+06, β=1.00
# INFO:bi2d.solution:Solving for f=1.74e+06, β=1.00
# INFO:bi2d.solution:Solving for f=2.40e+06, β=1.00
# INFO:bi2d.solution:Solving for f=3.29e+06, β=1.00
# INFO:bi2d.solution:Solving for f=4.52e+06, β=1.00
# INFO:bi2d.solution:Solving for f=6.21e+06, β=1.00
# INFO:bi2d.solution:Solving for f=8.53e+06, β=1.00
# INFO:bi2d.solution:Solving for f=1.17e+07, β=1.00
# INFO:bi2d.solution:Solving for f=1.61e+07, β=1.00
# INFO:bi2d.solution:Solving for f=2.21e+07, β=1.00
# INFO:bi2d.solution:Solving for f=3.04e+07, β=1.00
# INFO:bi2d.solution:Solving for f=4.18e+07, β=1.00
# INFO:bi2d.solution:Solving for f=5.74e+07, β=1.00
# INFO:bi2d.solution:Solving for f=7.88e+07, β=1.00
# INFO:bi2d.solution:Solving for f=1.08e+08, β=1.00
# INFO:bi2d.solution:Solving for f=1.49e+08, β=1.00
# INFO:bi2d.solution:Solving for f=2.04e+08, β=1.00
# INFO:bi2d.solution:Solving for f=2.81e+08, β=1.00
# INFO:bi2d.solution:Solving for f=3.86e+08, β=1.00
# INFO:bi2d.solution:Solving for f=5.30e+08, β=1.00
# INFO:bi2d.solution:Solving for f=7.28e+08, β=1.00
# INFO:bi2d.solution:Solving for f=1.00e+09, β=1.00
# CPU times: user 25min 9s, sys: 43.7 s, total: 25min 53s
# Wall time: 25min 51s

# %% [markdown]
# ## Plot impedances

# %%
import pylab
pylab.rcParams['figure.figsize'] = [12, 8]

# %%
for d in data:
    pylab.plot(d[:,0], d[:,1]*0.0254)
pylab.xscale("log")
pylab.xlabel("f")
pylab.ylabel(r"$\Re{z}$")
pylab.grid()
pylab.legend([r"$\beta$=" + f"{b}" for b in betas])
pylab.show()

# %%
for d in data:
    pylab.plot(d[:,0], d[:,2]*0.0254)
pylab.xscale("log")
pylab.xlabel("f")
pylab.ylim((-200, 60))
pylab.ylabel(r"$\Im{z}$")
pylab.grid()
pylab.legend([r"$\beta$=" + f"{b}" for b in betas])
pylab.show()
